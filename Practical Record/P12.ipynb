# %%
import random

# List of students
students = ["Manshi", "Roshni",  "Anjali", "Pragya", "Yukti","Komal"]

# Select CR randomly
cr = random.choice(students)
print("Selected CR:", cr)

# Shuffle the student list
random.shuffle(students)

# Print shuffled list
print("Shuffled Student List:", students)
# Out:
# Selected CR: Roshni
# Shuffled Student List: ['Manshi', 'Roshni', 'Pragya', 'Komal', 'Anjali', 'Yukti']
