# %%
import pandas as pd

# load dataset
df = pd.read_csv("C:/Users/komal/OneDrive/Desktop/MCA/Manshi Gupta/Python/Practical/student_performance.csv")

# first five records
print(df.head())

# shape of dataset
print("Shape:", df.shape)

# column names and data types
print("\nData Types:")
print(df.dtypes)

# missing values
print("\nMissing Values:")
print(df.isnull().sum())

# statistical summary
print("\nStatistical Summary:")
print(df.describe())
# Out:
#    Student_ID          Name  Age  Marks  Attendance
# 0         101  Rahul Sharma   20   85.0        92.5
# 1         102   Priya Patel   19   78.0        88.0
# 2         103    Amit Kumar   21   92.0        95.0
# 3         104   Sneha Gupta   20   67.0        82.5
# 4         105  Vikram Singh   22    NaN        90.0
# Shape: (15, 5)
#
# Data Types:
# Student_ID      int64
# Name           object
# Age             int64
# Marks         float64
# Attendance    float64
# dtype: object
#
# Missing Values:
# Student_ID    0
# Name          0
# Age           0
# Marks         2
# Attendance    1
# dtype: int64
#
# Statistical Summary:
#        Student_ID        Age      Marks  Attendance
# count   15.000000  15.000000  13.000000   14.000000
# mean   108.000000  20.333333  82.923077   89.642857
# std      4.472136   1.112697   9.114654    5.081749
# min    101.000000  19.000000  67.000000   80.000000
# 25%    104.500000  19.500000  78.000000   86.750000
# ...
