# %%
def reverse_vowels(sentence):
    vowels = "AEIOUaeiou"
    sentence = list(sentence)
    i, j = 0, len(sentence) - 1

    while i < j:
        if sentence[i] not in vowels:
            i += 1
        elif sentence[j] not in vowels:
            j -= 1
        else:
            sentence[i], sentence[j] = sentence[j], sentence[i]
            i += 1
            j -= 1
    return "".join(sentence)

text = input("Enter sentence: ")
print(f"Original String:{text}")
print("Reversed:", reverse_vowels(text))
# Out:
# Original String:sdejukou
# Reversed: sdujokue
