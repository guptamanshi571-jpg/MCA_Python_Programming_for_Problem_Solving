# %%
def reverse_number(num):
    reversed_num = 0

# Handle negative numbers by reversing the absolute value and then adding the sign back 
    is_negative = False
    if num < 0:
        is_negative = True
        num = abs (num)
    while num > 0:
        last_digit = num % 10   # Get the last digit
        reversed_num = (reversed_num * 10) + last_digit # Append the digit to the reversed number
        num //= 10 # Remove the last digit from the original number
    if is_negative:
         return -reversed_num
    else:
        return reversed_num

# Get input from the user
try:
    number = int(input("Enter an integer to reverse: ")) 
    reversed_result = reverse_number(number)
    print(f"The original number is:{number}")
    print (f"The reversed number is: {reversed_result}") 
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# The original number is:578932
# The reversed number is: 239875
