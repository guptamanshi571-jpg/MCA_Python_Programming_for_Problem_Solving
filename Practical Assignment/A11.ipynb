# %%
from calculator.add import add
from calculator.subtract import subtract
from calculator.operations import show_results

print("Addition:", add(20, 10))
print("Subtraction:", subtract(20, 10))

show_results()
# Out:
# Addition: 30
# Subtraction: 10
# Addition: 15
# Subtraction: 5
