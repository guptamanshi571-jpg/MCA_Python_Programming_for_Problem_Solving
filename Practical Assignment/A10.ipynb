# %%
from shapes import *

c = Circle(center=None, radius=5)
r = Rectangle(4, 6)

print("Circle Area:", c.area())
print("Rectangle Area:", r.area())

# Point class is NOT accessible
# p = Point(2, 3)   ❌ This will raise NameError
# Out:
# Circle Area: 78.53975
# Rectangle Area: 24
